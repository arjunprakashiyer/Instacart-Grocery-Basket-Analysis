# %% [markdown]
# ### Table of contents
#
# 1) Importing the Data set.<br>
# 2) Security Implications.<br>
# 3) Regional Segmentation of Data.<br>
# 4) Exclusion Flag. <br>
# 5) Customer Profiling. <br>
# 6) Visualization showing distribution of profiles. <br>
# 7) Descriptive statistics of customer profile. <br>
# 8) Comparing Customer profiles with Regions and Departments. <br>

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Creating the path variable
path = r'C:\Users\Arjun\Documents\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\Arjun\\Documents\\Instacart Basket Analysis'

# %%
# Importing the merged data set
instacart_with_customers = pd.read_pickle(os.path.join(path,'Data','Prepared Data','instacart_with_customers.pkl'))

# %%
#Validating the data set
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...    order_frequency_flag  first_name  last_name  gender  \
# 0         Soda  ...  Non-frequent customer.       Linda     Nguyen  Female
# 1         Soda  ...  Non-frequent customer.       Linda     Nguyen  Female
# 2         Soda  ...  Non-frequent customer.       Linda     Nguyen  Female
# 3         Soda  ...  Non-frequent customer.       Linda     Nguyen  Female
# 4         Soda  ...  Non-frequent customer.       Linda     Nguyen  Female
#
#      state age date_joined number_dependents  marital_status income
# 0  Alabama  31   2/17/2019                 3         married  40423
# 1  Alabama  31   2/17/2019                 3         married  40423
# 2  Alabama  31   2/17/2019                 3         married  40423
# 3  Alabama  31   2/17/2019                 3         married  40423
# 4  Alabama  31   2/17/2019                 3         married  40423
#
# [5 rows x 33 columns]

# %%
# checking the dimensions
instacart_with_customers.shape
# Out:
# (32404859, 33)

# %% [markdown]
# ### Question 2

# %% [markdown]
# **PII data Implications**

# %% [markdown]
# Customers first and last name are fields which forms part of PII data. Hence, these columns are being removed from the data set.

# %%
instacart_with_customers.drop(['first_name','last_name','_merge','prior_order_median'], axis = 1, inplace = True)

# %%
#Checking the updated data set
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  average_price  spending_flag    order_frequency_flag  \
# 0         Soda  ...       6.367797    Low Spender  Non-frequent customer.
# 1         Soda  ...       6.367797    Low Spender  Non-frequent customer.
# 2         Soda  ...       6.367797    Low Spender  Non-frequent customer.
# 3         Soda  ...       6.367797    Low Spender  Non-frequent customer.
# 4         Soda  ...       6.367797    Low Spender  Non-frequent customer.
#
#    gender    state age date_joined  number_dependents marital_status  income
# 0  Female  Alabama  31   2/17/2019                  3        married   40423
# 1  Female  Alabama  31   2/17/2019                  3        married   40423
# 2  Female  Alabama  31   2/17/2019                  3        married   40423
# 3  Female  Alabama  31   2/17/2019                  3        married   40423
# 4  Female  Alabama  31   2/17/2019                  3        married   40423
#
# [5 rows x 29 columns]

# %%
#Checking the data types
instacart_with_customers.dtypes
# Out:
# order_id                   int64
# user_id                   object
# order_number               int64
# order_day_of_week          int64
# order_hour_of_day          int64
# days_since_last_order    float64
# product_id                 int64
# add_to_cart_order          int64
# reordered                  int64
# product_name              object
# aisle_id                   int64
# department_id              int64
# prices                   float64
# price_range_loc           object
# busiest_day               object
# Busiest_days              object
# busiest_period_of_day     object
# max_order                  int64
# loyalty_flag              object
# average_price            float64
# spending_flag             object
# order_frequency_flag      object
# gender                    object
# state                     object
# age                        int64
# date_joined               object
# number_dependents          int64
# marital_status            object
# income                     int64
# dtype: object

# %% [markdown]
# ### Regional Segmentation of data

# %%
#First let's create lists for the Regions by adding states as contents of lists
northeast = ['Maine', 'New Hampshire', 'Vermont', 'Massachusetts', 'Rhode Island', 'Connecticut', 'New York', 'Pennsylvania', 'New Jersey']
midwest = ['Wisconsin', 'Michigan', 'Illinois', 'Indiana', 'Ohio', 'North Dakota', 'South Dakota', 'Nebraska', 'Kansas', 'Minnesota', 'Iowa', 'Missouri']
south = ['Delaware', 'Maryland', 'District of Columbia', 'Virginia', 'West Virginia', 'North Carolina', 'South Carolina', 'Georgia', 'Florida', 'Kentucky', 'Tennessee', 'Mississippi', 'Alabama', 'Oklahoma', 'Texas', 'Arkansas', 'Louisiana']
west = ['Idaho', 'Montana', 'Wyoming', 'Nevada', 'Utah', 'Colorado', 'Arizona', 'New Mexico', 'Alaska', 'Washington', 'Oregon', 'California', 'Hawaii']

# %%
#We are using loc function to move the states into the Region for the whole dataset
instacart_with_customers.loc[instacart_with_customers['state'].isin(northeast),'region'] = 'NorthEast'
instacart_with_customers.loc[instacart_with_customers['state'].isin(midwest),'region'] = 'MidWest'
instacart_with_customers.loc[instacart_with_customers['state'].isin(south),'region'] = 'South'
instacart_with_customers.loc[instacart_with_customers['state'].isin(west),'region'] = 'West'

# %%
#Validating the Region column in the dataset
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  spending_flag    order_frequency_flag  gender    state  \
# 0         Soda  ...    Low Spender  Non-frequent customer.  Female  Alabama
# 1         Soda  ...    Low Spender  Non-frequent customer.  Female  Alabama
# 2         Soda  ...    Low Spender  Non-frequent customer.  Female  Alabama
# 3         Soda  ...    Low Spender  Non-frequent customer.  Female  Alabama
# 4         Soda  ...    Low Spender  Non-frequent customer.  Female  Alabama
#
#   age date_joined number_dependents  marital_status income  region
# 0  31   2/17/2019                 3         married  40423   South
# 1  31   2/17/2019                 3         married  40423   South
# 2  31   2/17/2019                 3         married  40423   South
# 3  31   2/17/2019                 3         married  40423   South
# 4  31   2/17/2019                 3         married  40423   South
#
# [5 rows x 30 columns]

# %%
# Frequency Table
instacart_with_customers['region'].value_counts(dropna = False)
# Out:
# South        10791885
# West          8292913
# MidWest       7597325
# NorthEast     5722736
# Name: region, dtype: int64

# %%
# Creating a bar plot to show the customers of the company across Regions
customer_region = instacart_with_customers['region'].value_counts(dropna = False).plot.bar(color = ['blue','red','gray','silver'])

# %%
#Saving the above visualization locally by exporting the above chart
customer_region.figure.savefig(os.path.join(path,'Analysis','Visualizations','customers_region_bar.png'))

# %% [markdown]
# ### Question 3.2 - Spending Habits between Different US Regions

# %%
#Checking the difference in spending habits between the Regions
crosstab_spending_habits_region = pd.crosstab(instacart_with_customers['region'],instacart_with_customers['spending_flag'],dropna= False)

# %%
crosstab_spending_habits_region
# Out:
# spending_flag  High Spender  Low Spender
# region
# MidWest               29265      7568060
# NorthEast             18642      5704094
# South                 40579     10751306
# West                  31223      8261690

# %% [markdown]
# Analysis of the above spending Habits <br>
# 1) The high spenders are higher in number in South, but proportionally slightly higher in the MidWest. <br>
# 2) Based on the Cross Tab analysis, there does not seem to be very different spending habits in Regions with proportion to their population spending.

# %% [markdown]
# ### Question 4 - Exclusion Flag for Low Activity Customers

# %%
instacart_with_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 30 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int64
#  1   user_id                object
#  2   order_number           int64
#  3   order_day_of_week      int64
#  4   order_hour_of_day      int64
#  5   days_since_last_order  float64
#  6   product_id             int64
#  7   add_to_cart_order      int64
#  8   reordered              int64
#  9   product_name           object
#  10  aisle_id               int64
#  11  department_id          int64
#  12  prices                 float64
#  13  price_range_loc        object
#  14  busiest_day            object
#  15  Busiest_days           object
#  16  busiest_period_of_day  object
#  17  max_order              int64
#  18  loyalty_flag           object
#  19  average_price          float64
#  20  spending_flag          object
#  21  order_frequency_flag   object
#  22  gender                 object
#  23  state                  object
#  24  age                    int64
#  25  date_joined            object
#  26  number_dependents      int64
#  27  marital_status         object
#  28  income                 int64
#  29  region                 object
# dtypes: float64(3), int64(13), object(14)
# memory usage: 7.5+ GB

# %%
#By Viewing the columns, we can see that there is a max_order column which determines the number of orders
instacart_with_customers['max_order'].head()
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# Name: max_order, dtype: int64

# %%
#Creating an Exclusion Flag for Customers with less than 5 Orders
instacart_with_customers.loc[instacart_with_customers['max_order'] < 5, 'Order_Flag'] = 'Low-Activity-Customer'

# %%
instacart_with_customers.loc[instacart_with_customers['max_order'] >= 5, 'Order_Flag'] = 'High-Activity-Customer'

# %%
#Validate the Exclusion Flag Logic in the dataset
instacart_with_customers.head(10)
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
# 5   3367565       1             6                  2                  7
# 6    550135       1             7                  1                  9
# 7   3108588       1             8                  1                 14
# 8   2295261       1             9                  1                 16
# 9   2550362       1            10                  4                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
# 5                   19.0         196                  1          1
# 6                   20.0         196                  1          1
# 7                   14.0         196                  2          1
# 8                    0.0         196                  4          1
# 9                   30.0         196                  1          1
#
#   product_name  ...    order_frequency_flag  gender    state age date_joined  \
# 0         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 1         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 2         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 3         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 4         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 5         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 6         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 7         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 8         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 9         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
#
#   number_dependents marital_status  income region              Order_Flag
# 0                 3        married   40423  South  High-Activity-Customer
# 1                 3        married   40423  South  High-Activity-Customer
# 2                 3        married   40423  South  High-Activity-Customer
# 3                 3        married   40423  South  High-Activity-Customer
# 4                 3        married   40423  South  High-Activity-Customer
# 5                 3        married   40423  South  High-Activity-Customer
# 6                 3        married   40423  South  High-Activity-Customer
# 7                 3        married   40423  South  High-Activity-Customer
# 8                 3        married   40423  South  High-Activity-Customer
# 9                 3        married   40423  South  High-Activity-Customer
#
# [10 rows x 31 columns]

# %%
# Checking the Frequency distribution of the Exclusion Flag
instacart_with_customers['Order_Flag'].value_counts(dropna = False)
# Out:
# High-Activity-Customer    30964564
# Low-Activity-Customer      1440295
# Name: Order_Flag, dtype: int64

# %%
# Now, lets exclude the low-activity customers from the dataset and create a dataset for the High Activity Customers
instacart_high_customers = instacart_with_customers[instacart_with_customers['Order_Flag'] != 'Low-Activity-Customer']

# %%
#Checking the high customers subset of the whole dataset
instacart_high_customers.shape
# Out:
# (30964564, 31)

# %%
instacart_with_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 31 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int64
#  1   user_id                object
#  2   order_number           int64
#  3   order_day_of_week      int64
#  4   order_hour_of_day      int64
#  5   days_since_last_order  float64
#  6   product_id             int64
#  7   add_to_cart_order      int64
#  8   reordered              int64
#  9   product_name           object
#  10  aisle_id               int64
#  11  department_id          int64
#  12  prices                 float64
#  13  price_range_loc        object
#  14  busiest_day            object
#  15  Busiest_days           object
#  16  busiest_period_of_day  object
#  17  max_order              int64
#  18  loyalty_flag           object
#  19  average_price          float64
#  20  spending_flag          object
#  21  order_frequency_flag   object
#  22  gender                 object
#  23  state                  object
#  24  age                    int64
#  25  date_joined            object
#  26  number_dependents      int64
#  27  marital_status         object
#  28  income                 int64
#  29  region                 object
#  30  Order_Flag             object
# dtypes: float64(3), int64(13), object(15)
# memory usage: 7.7+ GB

# %%
instacart_with_customers['order_day_of_week']=instacart_with_customers['order_day_of_week'].astype('int8')
instacart_with_customers['order_hour_of_day']=instacart_with_customers['order_hour_of_day'].astype('int8')
instacart_with_customers['reordered']=instacart_with_customers['reordered'].astype('int8')
instacart_with_customers['max_order']=instacart_with_customers['max_order'].astype('int8')
instacart_with_customers['order_number']=instacart_with_customers['order_number'].astype('int16')
instacart_with_customers['age']=instacart_with_customers['age'].astype('int8')
instacart_with_customers['days_since_last_order'] = instacart_with_customers['days_since_last_order'].astype('float16')
instacart_with_customers['number_dependents']=instacart_with_customers['number_dependents'].astype('int8')

# %% [markdown]
# **Below is the Code to avoid the MemoryError in the Notebook**

# %%
instacart_high_customers['prices']=instacart_high_customers['prices'].astype('float16')
#instacart_high_customers['average_price']=instacart_high_customers['average_price'].astype('float16')
# Out:
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\1845234743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['prices']=instacart_high_customers['prices'].astype('float16')

# %%
instacart_high_customers['order_day_of_week']=instacart_high_customers['order_day_of_week'].astype('int8')
instacart_high_customers['order_hour_of_day']=instacart_high_customers['order_hour_of_day'].astype('int8')
#instacart_with_customers['reordered']=instacart_with_customers['reordered'].astype('int8')
instacart_high_customers['max_order']=instacart_high_customers['max_order'].astype('int8')
instacart_high_customers['order_number']=instacart_high_customers['order_number'].astype('int16')
instacart_high_customers['age']=instacart_high_customers['age'].astype('int8')
# Out:
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\242211662.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['order_day_of_week']=instacart_high_customers['order_day_of_week'].astype('int8')
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\242211662.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['order_hour_of_day']=instacart_high_customers['order_hour_of_day'].astype('int8')
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\242211662.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['max_order']=instacart_high_customers['max_order'].astype('int8')
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\242211662.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['order_number']=instacart_high_customers['order_number'].astype('int16')
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\242211662.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['age']=instacart_high_customers['age'].astype('int8')

# %%
instacart_high_customers['days_since_last_order']=instacart_high_customers['days_since_last_order'].astype('float16')
# Out:
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\2017941545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['days_since_last_order']=instacart_high_customers['days_since_last_order'].astype('float16')

# %%
#instacart_high_customers['product_id'] =instacart_high_customers['product_id'].astype('int32')
instacart_high_customers['reordered']=instacart_high_customers['reordered'].astype('int8')
instacart_high_customers['aisle_id']=instacart_high_customers['aisle_id'].astype('int8')
#ords_prods['order_id']=ords_prods['order_id'].astype('int32')
#instacart_with_customers['order_id']=instacart_with_customers['order_id'].astype('int8')
instacart_high_customers['add_to_cart_order']=instacart_high_customers['add_to_cart_order'].astype('int8')
# Out:
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\1413033562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['reordered']=instacart_high_customers['reordered'].astype('int8')
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\1413033562.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['aisle_id']=instacart_high_customers['aisle_id'].astype('int8')
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\1413033562.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['add_to_cart_order']=instacart_high_customers['add_to_cart_order'].astype('int8')

# %%
instacart_high_customers['department_id'] = instacart_high_customers['department_id'].astype('int8')
# Out:
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\443423941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['department_id'] = instacart_high_customers['department_id'].astype('int8')

# %%
instacart_high_customers['number_dependents'] = instacart_high_customers['number_dependents'].astype('int8')
# Out:
# C:\Users\Arjun\AppData\Local\Temp\ipykernel_3224\3044059920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   instacart_high_customers['number_dependents'] = instacart_high_customers['number_dependents'].astype('int8')

# %%
instacart_high_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30964564 entries, 0 to 32404854
# Data columns (total 31 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int64
#  1   user_id                object
#  2   order_number           int16
#  3   order_day_of_week      int8
#  4   order_hour_of_day      int8
#  5   days_since_last_order  float16
#  6   product_id             int64
#  7   add_to_cart_order      int8
#  8   reordered              int8
#  9   product_name           object
#  10  aisle_id               int8
#  11  department_id          int8
#  12  prices                 float16
#  13  price_range_loc        object
#  14  busiest_day            object
#  15  Busiest_days           object
#  16  busiest_period_of_day  object
#  17  max_order              int8
#  18  loyalty_flag           object
#  19  average_price          float64
#  20  spending_flag          object
#  21  order_frequency_flag   object
#  22  gender                 object
#  23  state                  object
#  24  age                    int8
#  25  date_joined            object
#  26  number_dependents      int8
#  27  marital_status         object
#  28  income                 int64
#  29  region                 object
#  30  Order_Flag             object
# dtypes: float16(2), float64(1), int16(1), int64(3), int8(9), object(15)
# memory usage: 5.0+ GB

# %% [raw]
# #Exporting the above sample dataset
# instacart_high_customers.to_pickle(os.path.join(path,'Data','Prepared Data', 'Instacart_High_Activity_customers.pkl'))

# %% [markdown]
# ### Question 5

# %%
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...    order_frequency_flag  gender    state age date_joined  \
# 0         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 1         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 2         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 3         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
# 4         Soda  ...  Non-frequent customer.  Female  Alabama  31   2/17/2019
#
#   number_dependents marital_status  income region              Order_Flag
# 0                 3        married   40423  South  High-Activity-Customer
# 1                 3        married   40423  South  High-Activity-Customer
# 2                 3        married   40423  South  High-Activity-Customer
# 3                 3        married   40423  South  High-Activity-Customer
# 4                 3        married   40423  South  High-Activity-Customer
#
# [5 rows x 31 columns]

# %% [markdown]
# **Age Profile**

# %%
# I will be profiling the people into 5 categories based on age in the dataset - Child(<10),Adolescent(10-17), Mid Age(18-34), Adult(35-64) and Old Age(>65)
instacart_with_customers.loc[instacart_with_customers['age'] < 10, 'Age-Profile'] = 'Child'
instacart_with_customers.loc[(instacart_with_customers['age'] >= 10) & (instacart_with_customers['age'] < 18) , 'Age-Profile'] = 'Adolescent'
instacart_with_customers.loc[(instacart_with_customers['age'] >= 18) & (instacart_with_customers['age'] < 35) , 'Age-Profile'] = 'Mid Age'
instacart_with_customers.loc[(instacart_with_customers['age'] >= 35) & (instacart_with_customers['age'] < 65) , 'Age-Profile'] = 'Adult'
instacart_with_customers.loc[instacart_with_customers['age'] >= 65 , 'Age-Profile'] = 'Old Age'

# %%
#Viewing the newly added age profile column
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  gender    state  age date_joined number_dependents  \
# 0         Soda  ...  Female  Alabama   31   2/17/2019                 3
# 1         Soda  ...  Female  Alabama   31   2/17/2019                 3
# 2         Soda  ...  Female  Alabama   31   2/17/2019                 3
# 3         Soda  ...  Female  Alabama   31   2/17/2019                 3
# 4         Soda  ...  Female  Alabama   31   2/17/2019                 3
#
#   marital_status income  region              Order_Flag  Age-Profile
# 0        married  40423   South  High-Activity-Customer      Mid Age
# 1        married  40423   South  High-Activity-Customer      Mid Age
# 2        married  40423   South  High-Activity-Customer      Mid Age
# 3        married  40423   South  High-Activity-Customer      Mid Age
# 4        married  40423   South  High-Activity-Customer      Mid Age
#
# [5 rows x 32 columns]

# %%
# Viewing the frequency distribution of the age profile column
instacart_with_customers['Age-Profile'].value_counts(dropna = False)
# Out:
# Adult      15202120
# Mid Age     8627655
# Old Age     8575084
# Name: Age-Profile, dtype: int64

# %%
# Checking the dimension of the dataset
instacart_with_customers.shape
# Out:
# (32404859, 32)

# %% [markdown]
# **Income Profiling**

# %%
#First, lets plot a histogram for viewing the distribution of the income variable
income_histogram = instacart_with_customers['income'].plot.hist(bins = 60)

# %% [markdown]
# As we can see from the above histogram, majority of Incomes are less than 175K.I will be using 4 Income categories to profile the Income variable based on the above distribution. 1-75K -> Low Income, 75k-125k -> Middle Income, 125K-175K -> High-Income and Income > 175k as Very High Income.

# %%
instacart_with_customers.loc[instacart_with_customers['income'] < 75000, 'Income-Profile'] = 'Low-Income'
instacart_with_customers.loc[(instacart_with_customers['income'] >= 75000) & (instacart_with_customers['income'] < 125000), 'Income-Profile'] = 'Middle-Income'
instacart_with_customers.loc[(instacart_with_customers['income'] >= 125000) & (instacart_with_customers['income'] < 175000), 'Income-Profile'] = 'High-Income'
instacart_with_customers.loc[instacart_with_customers['income'] >= 175000, 'Income-Profile'] = 'Very-High-Income'

# %%
#Validating the new column for Income Profiling
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...    state  age  date_joined number_dependents  \
# 0         Soda  ...  Alabama   31    2/17/2019                 3
# 1         Soda  ...  Alabama   31    2/17/2019                 3
# 2         Soda  ...  Alabama   31    2/17/2019                 3
# 3         Soda  ...  Alabama   31    2/17/2019                 3
# 4         Soda  ...  Alabama   31    2/17/2019                 3
#
#   marital_status income region              Order_Flag Age-Profile  \
# 0        married  40423  South  High-Activity-Customer     Mid Age
# 1        married  40423  South  High-Activity-Customer     Mid Age
# 2        married  40423  South  High-Activity-Customer     Mid Age
# 3        married  40423  South  High-Activity-Customer     Mid Age
# 4        married  40423  South  High-Activity-Customer     Mid Age
#
#    Income-Profile
# 0      Low-Income
# 1      Low-Income
# 2      Low-Income
# 3      Low-Income
# 4      Low-Income
#
# [5 rows x 33 columns]

# %%
# Checking the Frequency distribution of the Income variable
instacart_with_customers['Income-Profile'].value_counts(dropna = False)
# Out:
# Middle-Income       13331136
# Low-Income          10442766
# High-Income          8323613
# Very-High-Income      307344
# Name: Income-Profile, dtype: int64

# %% [markdown]
# **Vegetarian and Meat-Eating**

# %%
# I will use the department ids of 12 and 16 to categorize the customers within the dataset to Vegetarian and Meat Eating.
# Will create a vegetarian_flag for the customers
# First creating a crosstab of department_id and user_id
veg_cross = pd.crosstab(instacart_with_customers['department_id'], instacart_with_customers['user_id'], dropna = False)

# %%
#Viewing the Cross Tab values
veg_cross.head()
# Out:
# user_id        1  10  100  1000  10000  100000  100001  100002  100003  \
# department_id
# 1              0   1    3     5     56       0      16       7       3
# 2              0   0    0     0      0       0       0       0       0
# 3              0   0    2     1     56       8      17       1       2
# 4              5  72   10    34    340      51     393       0      10
# 5              0   0    0     0      0       2       0       0       0
#
# user_id        100004  ...  99990  99991  99992  99993  99994  99995  99996  \
# department_id          ...
# 1                   0  ...     13     16      4      9     12      7     51
# 2                   0  ...      0      1      0      0      0      0      1
# 3                   0  ...      1      0      2      4      7      2      4
# 4                   0  ...    196     78      4     22     68     10     20
# 5                   0  ...      0      0      0      0      0      4      0
#
# user_id        99997  99998  99999
# department_id
# 1                  4      2      9
# 2                  0      0      0
# 3                  3      0      7
# 4                 10     14    129
# 5                  0      0      0
#
# [5 rows x 206209 columns]

# %%
veg_map = dict()
for user in veg_cross:
    # This is done to create a list to get the userid for types
    user_list = veg_cross[user].tolist()
    if user_list[11] == 0 and user_list[15] == 0:
        veg_map[user] = 'Vegetarian'
    else:
        veg_map[user] = 'Meat-Eating'

# %%
#Now, lets update the flag to the users in the dataset based on the userid
veg_list = []
for user in instacart_with_customers['user_id']:
    veg_list.append(veg_map[user])
    
instacart_with_customers['Veg-Flag'] = veg_list

# %%
# Lets check the new flag in the dataset
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  age  date_joined  number_dependents marital_status  \
# 0         Soda  ...   31    2/17/2019                  3        married
# 1         Soda  ...   31    2/17/2019                  3        married
# 2         Soda  ...   31    2/17/2019                  3        married
# 3         Soda  ...   31    2/17/2019                  3        married
# 4         Soda  ...   31    2/17/2019                  3        married
#
#   income region              Order_Flag  Age-Profile Income-Profile  \
# 0  40423  South  High-Activity-Customer      Mid Age     Low-Income
# 1  40423  South  High-Activity-Customer      Mid Age     Low-Income
# 2  40423  South  High-Activity-Customer      Mid Age     Low-Income
# 3  40423  South  High-Activity-Customer      Mid Age     Low-Income
# 4  40423  South  High-Activity-Customer      Mid Age     Low-Income
#
#       Veg-Flag
# 0  Meat-Eating
# 1  Meat-Eating
# 2  Meat-Eating
# 3  Meat-Eating
# 4  Meat-Eating
#
# [5 rows x 34 columns]

# %%
#Checking the Frequency distribution
instacart_with_customers['Veg-Flag'].value_counts(dropna = False)
# Out:
# Meat-Eating    32021432
# Vegetarian       383427
# Name: Veg-Flag, dtype: int64

# %% [markdown]
# **Marital Status and Number of Dependents**

# %%
#The columns used for this profiling are Marital status and the number of dependents

# %%
instacart_with_customers['marital_status'].value_counts(dropna = False)
# Out:
# married                             22756753
# single                               5325691
# divorced/widowed                     2771812
# living with parents and siblings     1550603
# Name: marital_status, dtype: int64

# %%
#lets check the distribution of the number of dependents
instacart_with_customers['number_dependents'].plot.hist(bins = 10)
plt.title("Number of dependents")
# Out:
# Text(0.5, 1.0, 'Number of dependents')

# %%
#To get the frequency table of both the above factors, I am using crosstab
fam_dep_crosstab = pd.crosstab(instacart_with_customers['marital_status'], instacart_with_customers['number_dependents'], dropna = False)

# %%
#Viewing the Crosstab
fam_dep_crosstab
# Out:
# number_dependents                       0        1        2        3
# marital_status
# divorced/widowed                  2771812        0        0        0
# living with parents and siblings        0   530200   507963   512440
# married                                 0  7550904  7583180  7622669
# single                            5325691        0        0        0

# %% [markdown]
# The above table shows that Single and Divorced/Widowed people in the dataset does not have dependents and married people have dependents. We will have a flag which shows whether customers have dependents or not

# %%
#Dependent-Flag
instacart_with_customers.loc[instacart_with_customers['number_dependents'] == 0, 'Dependent-Flag'] = 'No-dependents'
instacart_with_customers.loc[instacart_with_customers['number_dependents'] >= 1, 'Dependent-Flag'] = 'With Dependents'

# %%
#Checking the dependent flag
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  date_joined  number_dependents  marital_status income  \
# 0         Soda  ...    2/17/2019                  3         married  40423
# 1         Soda  ...    2/17/2019                  3         married  40423
# 2         Soda  ...    2/17/2019                  3         married  40423
# 3         Soda  ...    2/17/2019                  3         married  40423
# 4         Soda  ...    2/17/2019                  3         married  40423
#
#   region              Order_Flag Age-Profile  Income-Profile     Veg-Flag  \
# 0  South  High-Activity-Customer     Mid Age      Low-Income  Meat-Eating
# 1  South  High-Activity-Customer     Mid Age      Low-Income  Meat-Eating
# 2  South  High-Activity-Customer     Mid Age      Low-Income  Meat-Eating
# 3  South  High-Activity-Customer     Mid Age      Low-Income  Meat-Eating
# 4  South  High-Activity-Customer     Mid Age      Low-Income  Meat-Eating
#
#     Dependent-Flag
# 0  With Dependents
# 1  With Dependents
# 2  With Dependents
# 3  With Dependents
# 4  With Dependents
#
# [5 rows x 35 columns]

# %%
# Checking the frequency distribution
instacart_with_customers['Dependent-Flag'].value_counts(dropna = False)
# Out:
# With Dependents    24307356
# No-dependents       8097503
# Name: Dependent-Flag, dtype: int64

# %% [markdown]
# **Marital Status and Dependents**

# %%
# Family status flag
instacart_with_customers.loc[(instacart_with_customers['marital_status'] == 'married') & (instacart_with_customers['number_dependents'] == 1), 'Family-Status'] = 'Married with no children'
instacart_with_customers.loc[(instacart_with_customers['marital_status'] == 'married') & (instacart_with_customers['number_dependents'] > 1), 'Family-Status'] = 'Married with children'
instacart_with_customers.loc[(instacart_with_customers['marital_status'] != 'married') & (instacart_with_customers['number_dependents'] == 0), 'Family-Status'] = 'Single with no children'
instacart_with_customers.loc[(instacart_with_customers['marital_status'] != 'married') & (instacart_with_customers['number_dependents'] >= 1), 'Family-Status'] = 'Single with dependents'

# %%
#View the above flag
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  number_dependents  marital_status  income region  \
# 0         Soda  ...                  3         married   40423  South
# 1         Soda  ...                  3         married   40423  South
# 2         Soda  ...                  3         married   40423  South
# 3         Soda  ...                  3         married   40423  South
# 4         Soda  ...                  3         married   40423  South
#
#                Order_Flag Age-Profile Income-Profile     Veg-Flag  \
# 0  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
# 1  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
# 2  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
# 3  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
# 4  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
#
#     Dependent-Flag          Family-Status
# 0  With Dependents  Married with children
# 1  With Dependents  Married with children
# 2  With Dependents  Married with children
# 3  With Dependents  Married with children
# 4  With Dependents  Married with children
#
# [5 rows x 36 columns]

# %%
# Frequency distribution of the family status flag
instacart_with_customers['Family-Status'].value_counts(dropna = False)
# Out:
# Married with children       15205849
# Single with no children      8097503
# Married with no children     7550904
# Single with dependents       1550603
# Name: Family-Status, dtype: int64

# %%
instacart_with_customers.shape
# Out:
# (32404859, 36)

# %% [markdown]
# **Shopping Habits by Age and Day of the week**

# %% [markdown]
# We will now check the Shopping habits by the Age profile and orders by day of the week and calculate the frequency distribution

# %%
# First lets check the distribution of the Age profile variable
instacart_with_customers['Age-Profile'].value_counts(dropna = False)
# Out:
# Adult      15202120
# Mid Age     8627655
# Old Age     8575084
# Name: Age-Profile, dtype: int64

# %%
# Now, lets perform a crosstab on two variables age profile and order_day_of_week
shopping_habits_crosstab = pd.crosstab(instacart_with_customers['Age-Profile'], instacart_with_customers['order_day_of_week'], dropna = False)

# %%
shopping_habits_crosstab
# Out:
# order_day_of_week        0        1        2        3        4        5  \
# Age-Profile
# Adult              2905788  2653392  1983553  1801699  1774452  1972681
# Mid Age            1655160  1523713  1115913  1015872  1011128  1119749
# Old Age            1643234  1483125  1114364  1022963   998222  1113361
#
# order_day_of_week        6
# Age-Profile
# Adult              2110555
# Mid Age            1186120
# Old Age            1199815

# %%
# I will create a flag based on Weekday and Weekend Shopper based on the above age profiles
instacart_with_customers.loc[(instacart_with_customers['Age-Profile'] == 'Adult') & (instacart_with_customers['order_day_of_week'] <= 1), 'Shopping-Habits-Profile'] = 'Weekend Adult Shopper'
instacart_with_customers.loc[(instacart_with_customers['Age-Profile'] == 'Adult') & (instacart_with_customers['order_day_of_week'] > 1), 'Shopping-Habits-Profile'] = 'Weekday Adult Shopper'
instacart_with_customers.loc[(instacart_with_customers['Age-Profile'] == 'Mid Age') & (instacart_with_customers['order_day_of_week'] <= 1), 'Shopping-Habits-Profile'] = 'Weekend Mid Age Shopper'
instacart_with_customers.loc[(instacart_with_customers['Age-Profile'] == 'Mid Age') & (instacart_with_customers['order_day_of_week'] > 1), 'Shopping-Habits-Profile'] = 'Weekday Mid Age Shopper'
instacart_with_customers.loc[(instacart_with_customers['Age-Profile'] == 'Old Age') & (instacart_with_customers['order_day_of_week'] <= 1), 'Shopping-Habits-Profile'] = 'Weekend Old Age Shopper'
instacart_with_customers.loc[(instacart_with_customers['Age-Profile'] == 'Old Age') & (instacart_with_customers['order_day_of_week'] > 1), 'Shopping-Habits-Profile'] = 'Weekday Old Age Shopper'

# %%
#Checking the above flag
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  ...  marital_status  income  region              Order_Flag  \
# 0         Soda  ...         married   40423   South  High-Activity-Customer
# 1         Soda  ...         married   40423   South  High-Activity-Customer
# 2         Soda  ...         married   40423   South  High-Activity-Customer
# 3         Soda  ...         married   40423   South  High-Activity-Customer
# 4         Soda  ...         married   40423   South  High-Activity-Customer
#
#   Age-Profile Income-Profile     Veg-Flag   Dependent-Flag  \
# 0     Mid Age     Low-Income  Meat-Eating  With Dependents
# 1     Mid Age     Low-Income  Meat-Eating  With Dependents
# 2     Mid Age     Low-Income  Meat-Eating  With Dependents
# 3     Mid Age     Low-Income  Meat-Eating  With Dependents
# 4     Mid Age     Low-Income  Meat-Eating  With Dependents
#
#            Family-Status  Shopping-Habits-Profile
# 0  Married with children  Weekday Mid Age Shopper
# 1  Married with children  Weekday Mid Age Shopper
# 2  Married with children  Weekday Mid Age Shopper
# 3  Married with children  Weekday Mid Age Shopper
# 4  Married with children  Weekday Mid Age Shopper
#
# [5 rows x 37 columns]

# %%
# Frequency Distribution of the Shopping Profiles
instacart_with_customers['Shopping-Habits-Profile'].value_counts(dropna = False)
# Out:
# Weekday Adult Shopper      9642940
# Weekend Adult Shopper      5559180
# Weekday Mid Age Shopper    5448782
# Weekday Old Age Shopper    5448725
# Weekend Mid Age Shopper    3178873
# Weekend Old Age Shopper    3126359
# Name: Shopping-Habits-Profile, dtype: int64

# %% [markdown]
# **Shopping Habits by Age and Hour of the Day**

# %%
# First lets check the distribution of the Age profile variable
instacart_with_customers['Age-Profile'].value_counts(dropna = False)
# Out:
# Adult      15202120
# Mid Age     8627655
# Old Age     8575084
# Name: Age-Profile, dtype: int64

# %%
# Now, lets perform a crosstab on two variables age profile and order_hour_of_day
shopping_profile_crosstab = pd.crosstab(instacart_with_customers['Age-Profile'], instacart_with_customers['order_hour_of_day'],dropna = False)

# %%
pd.options.display.max_columns = 100

# %%
#Viewing the above crosstab
shopping_profile_crosstab
# Out:
# order_hour_of_day      0      1      2      3      4      5       6       7   \
# Age-Profile
# Adult              102288  54058  31721  23189  24265  40492  132991  412961
# Mid Age             59869  31506  19344  14125  14650  23420   79913  237834
# Old Age             56612  30136  18310  13967  14327  24049   77589  240259
#
# order_hour_of_day      8        9        10       11       12       13  \
# Age-Profile
# Adult              806846  1147851  1293892  1283649  1228776  1253063
# Mid Age            454428   654815   738973   732843   697460   706998
# Old Age            456844   651537   728895   719648   692296   700893
#
# order_hour_of_day       14       15       16      17      18      19      20  \
# Age-Profile
# Adult              1260916  1252766  1189448  984191  770418  587901  457628
# Mid Age             715394   713018   676461  550553  429137  334051  260481
# Old Age             712826   696360   669293  552910  436947  336353  258047
#
# order_hour_of_day      21      22      23
# Age-Profile
# Adult              373869  297406  191535
# Mid Age            208937  169177  104268
# Old Age            212831  167642  106513

# %%
# Will find the largest value and its columns for 3 Age-profiles
shopping_profile_crosstab.max(axis = 1)
# Out:
# Age-Profile
# Adult      1293892
# Mid Age     738973
# Old Age     728895
# dtype: int64

# %%
shopping_profile_crosstab.idxmax(axis =1)
# Out:
# Age-Profile
# Adult      10
# Mid Age    10
# Old Age    10
# dtype: int64

# %%
# As we can see that the most popular hour of the day where in orders are mostly placed, it is 10 AM. We need to make sure all the inventory
# are in stock at that time during the day.

# %% [markdown]
# **Family Status and Orders of Day of week**

# %%
# First lets check the distribution of the Family profile variable
instacart_with_customers['Family-Status'].value_counts(dropna = False)
# Out:
# Married with children       15205849
# Single with no children      8097503
# Married with no children     7550904
# Single with dependents       1550603
# Name: Family-Status, dtype: int64

# %%
family_order_crosstab = pd.crosstab(instacart_with_customers['Family-Status'], instacart_with_customers['order_day_of_week'],dropna = False)

# %%
family_order_crosstab
# Out:
# order_day_of_week               0        1        2        3        4  \
# Family-Status
# Married with children     2914885  2648079  1985233  1805945  1771422
# Married with no children  1443764  1315991   977957   892921   886381
# Single with dependents     295224   271393   201511   182315   180794
# Single with no children   1550309  1424767  1049129   959353   945205
#
# order_day_of_week               5        6
# Family-Status
# Married with children     1964855  2115430
# Married with no children   980588  1053302
# Single with dependents     203203   216163
# Single with no children   1057145  1111595

# %% [markdown]
# I will create a flag based on the above 4 Family status and with weekday and weekend shoppers

# %%
instacart_with_customers.loc[(instacart_with_customers['Family-Status'] == 'Married with children') & (instacart_with_customers['order_day_of_week'] <= 1), 'Shopping-Family-Profile'] = 'Weekday Married with children Shopper'
instacart_with_customers.loc[(instacart_with_customers['Family-Status'] == 'Married with children') & (instacart_with_customers['order_day_of_week'] > 1), 'Shopping-Family-Profile'] = 'Weekend Married with children Shopper'
instacart_with_customers.loc[(instacart_with_customers['Family-Status'] == 'Married with no children') & (instacart_with_customers['order_day_of_week'] <= 1), 'Shopping-Family-Profile'] = 'Weekday Married with no children Shopper'
instacart_with_customers.loc[(instacart_with_customers['Family-Status'] == 'Married with no children') & (instacart_with_customers['order_day_of_week'] > 1), 'Shopping-Family-Profile'] = 'Weekend Married with no children Shopper'
instacart_with_customers.loc[(instacart_with_customers['Family-Status'] == 'Single with dependents') & (instacart_with_customers['order_day_of_week'] <= 1), 'Shopping-Family-Profile'] = 'Weekday Single with dependents Shopper'
instacart_with_customers.loc[(instacart_with_customers['Family-Status'] == 'Single with dependents') & (instacart_with_customers['order_day_of_week'] > 1), 'Shopping-Family-Profile'] = 'Weekend Single with dependents Shopper'
instacart_with_customers.loc[(instacart_with_customers['Family-Status'] == 'Single with no children') & (instacart_with_customers['order_day_of_week'] <= 1), 'Shopping-Family-Profile'] = 'Weekday Single with no children Shopper'
instacart_with_customers.loc[(instacart_with_customers['Family-Status'] == 'Single with no children') & (instacart_with_customers['order_day_of_week'] > 1), 'Shopping-Family-Profile'] = 'Weekend Single with no children Shopper'

# %%
#Checking the newly added flag
instacart_with_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest_day  Busiest_days busiest_period_of_day  max_order  \
# 0  Regularly Busy   Normal Days        Average Orders         10
# 1  Regularly Busy  Slowest Days        Average Orders         10
# 2  Regularly Busy  Slowest Days           Most Orders         10
# 3      Least Busy  Slowest Days        Average Orders         10
# 4      Least Busy  Slowest Days           Most Orders         10
#
#    loyalty_flag  average_price spending_flag    order_frequency_flag  gender  \
# 0  New Customer       6.367797   Low Spender  Non-frequent customer.  Female
# 1  New Customer       6.367797   Low Spender  Non-frequent customer.  Female
# 2  New Customer       6.367797   Low Spender  Non-frequent customer.  Female
# 3  New Customer       6.367797   Low Spender  Non-frequent customer.  Female
# 4  New Customer       6.367797   Low Spender  Non-frequent customer.  Female
#
#      state  age date_joined  number_dependents marital_status  income region  \
# 0  Alabama   31   2/17/2019                  3        married   40423  South
# 1  Alabama   31   2/17/2019                  3        married   40423  South
# 2  Alabama   31   2/17/2019                  3        married   40423  South
# 3  Alabama   31   2/17/2019                  3        married   40423  South
# 4  Alabama   31   2/17/2019                  3        married   40423  South
#
#                Order_Flag Age-Profile Income-Profile     Veg-Flag  \
# 0  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
# 1  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
# 2  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
# 3  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
# 4  High-Activity-Customer     Mid Age     Low-Income  Meat-Eating
#
#     Dependent-Flag          Family-Status  Shopping-Habits-Profile  \
# 0  With Dependents  Married with children  Weekday Mid Age Shopper
# 1  With Dependents  Married with children  Weekday Mid Age Shopper
# 2  With Dependents  Married with children  Weekday Mid Age Shopper
# 3  With Dependents  Married with children  Weekday Mid Age Shopper
# 4  With Dependents  Married with children  Weekday Mid Age Shopper
#
#                  Shopping-Family-Profile
# 0  Weekend Married with children Shopper
# 1  Weekend Married with children Shopper
# 2  Weekend Married with children Shopper
# 3  Weekend Married with children Shopper
# 4  Weekend Married with children Shopper

# %%
#Checking the Frequency distribution of the flag
instacart_with_customers['Shopping-Family-Profile'].value_counts(dropna = False)
# Out:
# Weekend Married with children Shopper       9642885
# Weekday Married with children Shopper       5562964
# Weekend Single with no children Shopper     5122427
# Weekend Married with no children Shopper    4791149
# Weekday Single with no children Shopper     2975076
# Weekday Married with no children Shopper    2759755
# Weekend Single with dependents Shopper       983986
# Weekday Single with dependents Shopper       566617
# Name: Shopping-Family-Profile, dtype: int64

# %% [markdown]
# ## Question 6

# %% [markdown]
# **Visualization for Distribution of Profiles**

# %% [markdown]
# **Age Profile**

# %%
age_profile = instacart_with_customers['Age-Profile'].value_counts(dropna = False).plot.bar(color = ['green','blue','red'])
plt.title('Age-Profile of customers')
# Out:
# Text(0.5, 1.0, 'Age-Profile of customers')

# %%
#Saving the visualization to the folder 
age_profile.figure.savefig(os.path.join(path,'Analysis','Visualizations','Customers_Age-Profile.png'))

# %% [markdown]
# **Age-Profile with Labels using bar_label function of matplotlib**

# %%
df = pd.DataFrame({'Adult': 15202120, 'Mid Age': 8627655, 'Old Age': 8575084}, index=['Age Profile'])
ax = df.plot.bar()

for container in ax.containers:
    ax.bar_label(container,padding=1)

# %% [markdown]
# **Income Profile**

# %%
income_profile = instacart_with_customers['Income-Profile'].value_counts(dropna = False).plot.bar(color = ['red','blue','green','purple'])

# %%
#Saving the visualization within the local folder
income_profile.figure.savefig(os.path.join(path,'Analysis','Visualizations','Income-Profile.png'))

# %% [markdown]
# **Vegetarian Flag**

# %%
veg_flag = instacart_with_customers['Veg-Flag'].value_counts(dropna = False).plot.bar()

# %%
#Saving the visualization of the folder
veg_flag.figure.savefig(os.path.join(path,'Analysis','Visualizations','Vegetarian_Flag.png'))

# %% [markdown]
# **Number of Dependents**

# %%
number_depend = instacart_with_customers['number_dependents'].plot.hist(bins = 10)
plt.title("Number of dependents")
# Out:
# Text(0.5, 1.0, 'Number of dependents')

# %% [markdown]
# **Family Status**

# %%
family_status = instacart_with_customers['Family-Status'].value_counts(dropna = False).plot.bar(color = ['red','blue','green','yellow'])

# %%
#Saving the visualization
family_status.figure.savefig(os.path.join(path,'Analysis','Visualizations','Family_status.png'))

# %% [markdown]
# **Shopping Habits by Age and Day of the week**

# %%
shopping_profile = instacart_with_customers['Shopping-Habits-Profile'].value_counts(dropna = False).plot.bar()

# %%
#Saving the visualization
shopping_profile.figure.savefig(os.path.join(path,'Analysis','Visualizations','Shopping_Profile.png'))

# %% [markdown]
# **Family Status and Orders of Day of week**

# %%
family_shop_profile = instacart_with_customers['Shopping-Family-Profile'].value_counts(dropna = False).plot.bar()

# %%
#Saving the visualization
family_shop_profile.figure.savefig(os.path.join(path,'Analysis','Visualizations','Family_shop_Profile.png'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# **Aggregate the max, mean, and min variables on a customer-profile level for usage frequency and expenditure.**

# %%
instacart_with_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 38 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   order_id                 int64
#  1   user_id                  object
#  2   order_number             int16
#  3   order_day_of_week        int8
#  4   order_hour_of_day        int8
#  5   days_since_last_order    float16
#  6   product_id               int64
#  7   add_to_cart_order        int64
#  8   reordered                int8
#  9   product_name             object
#  10  aisle_id                 int64
#  11  department_id            int64
#  12  prices                   float64
#  13  price_range_loc          object
#  14  busiest_day              object
#  15  Busiest_days             object
#  16  busiest_period_of_day    object
#  17  max_order                int8
#  18  loyalty_flag             object
#  19  average_price            float64
#  20  spending_flag            object
#  21  order_frequency_flag     object
#  22  gender                   object
#  23  state                    object
#  24  age                      int8
#  25  date_joined              object
#  26  number_dependents        int8
#  27  marital_status           object
#  28  income                   int64
#  29  region                   object
#  30  Order_Flag               object
#  31  Age-Profile              object
#  32  Income-Profile           object
#  33  Veg-Flag                 object
#  34  Dependent-Flag           object
#  35  Family-Status            object
#  36  Shopping-Habits-Profile  object
#  37  Shopping-Family-Profile  object
# dtypes: float16(1), float64(2), int16(1), int64(6), int8(6), object(22)
# memory usage: 7.8+ GB

# %% [markdown]
# **Age**

# %%
#Age Profile Aggregate functions

# %%
instacart_with_customers.groupby('Age-Profile').agg({'days_since_last_order': ['min','mean','max'],'prices': ['min','mean','max']})
# Out:
#             days_since_last_order                  prices
#                               min       mean   max    min      mean   max
# Age-Profile
# Adult                         0.0  11.109375  30.0    1.0  7.790981  25.0
# Mid Age                       0.0  11.117188  30.0    1.0  7.785839  25.0
# Old Age                       0.0  11.078125  30.0    1.0  7.796662  25.0

# %% [markdown]
# The Usage frequency and prices remain the same across all Age Profiles

# %% [markdown]
# **Income**

# %%
#Income Profile Aggregate Functions

# %%
instacart_with_customers.groupby('Income-Profile').agg({'days_since_last_order': ['min','mean','max'],'prices': ['min','mean','max']})
# Out:
#                  days_since_last_order                  prices
#                                    min       mean   max    min      mean   max
# Income-Profile
# High-Income                        0.0  11.054688  30.0    1.0  7.963370  25.0
# Low-Income                         0.0  11.242188  30.0    1.0  7.434729  25.0
# Middle-Income                      0.0  11.046875  30.0    1.0  7.962579  25.0
# Very-High-Income                   0.0  10.242188  30.0    1.0  7.797849  25.0

# %% [markdown]
# The Usage frequency is same for range of Low to High Income. However, customers having Very High Income order more frequently. The Prices remain the same across all the income profiles.

# %% [markdown]
# **Vegetarian Flag**

# %%
#Aggregate functions based on the Vegetarian flag

# %%
instacart_with_customers.groupby('Veg-Flag').agg({'days_since_last_order': ['min','mean','max'],'prices': ['min','mean','max']})
# Out:
#             days_since_last_order                prices
#                               min     mean   max    min      mean   max
# Veg-Flag
# Meat-Eating                   0.0  11.0625  30.0    1.0  7.800469  25.0
# Vegetarian                    0.0  14.7500  30.0    1.0  7.009920  20.0

# %% [markdown]
# Meat Eating customers tend to shop more frequently than Vegetarian customers. The prices of the orders are also higher.

# %% [markdown]
# **Family Status**

# %%
#Aggregate functions based on the Family status flag.

# %%
instacart_with_customers.groupby('Family-Status').agg({'days_since_last_order': ['min','mean','max'],'prices': ['min','mean','max']})
# Out:
#                          days_since_last_order                  prices  \
#                                            min       mean   max    min
# Family-Status
# Married with children                      0.0  11.117188  30.0    1.0
# Married with no children                   0.0  11.109375  30.0    1.0
# Single with dependents                     0.0  11.046875  30.0    1.0
# Single with no children                    0.0  11.078125  30.0    1.0
#
#
#                               mean   max
# Family-Status
# Married with children     7.788331  25.0
# Married with no children  7.795825  25.0
# Single with dependents    7.800802  25.0
# Single with no children   7.790097  25.0

# %% [markdown]
# There are no major differences in the usage frequency and prices across customers with different family status.

# %% [markdown]
# **Shopping Habits by Age and Day of the week**

# %%
#Aggregate functions based on the Shopping habits by the Customers based on the Age Profile and the day of the week of Orders

# %%
instacart_with_customers.groupby('Shopping-Habits-Profile').agg({'days_since_last_order': ['min','mean','max'],'prices': ['min','mean','max']})
# Out:
#                         days_since_last_order                  prices  \
#                                           min       mean   max    min
# Shopping-Habits-Profile
# Weekday Adult Shopper                     0.0  10.914062  30.0    1.0
# Weekday Mid Age Shopper                   0.0  10.906250  30.0    1.0
# Weekday Old Age Shopper                   0.0  10.859375  30.0    1.0
# Weekend Adult Shopper                     0.0  11.445312  30.0    1.0
# Weekend Mid Age Shopper                   0.0  11.492188  30.0    1.0
# Weekend Old Age Shopper                   0.0  11.460938  30.0    1.0
#
#
#                              mean   max
# Shopping-Habits-Profile
# Weekday Adult Shopper    7.779497  25.0
# Weekday Mid Age Shopper  7.773048  25.0
# Weekday Old Age Shopper  7.786453  25.0
# Weekend Adult Shopper    7.810902  25.0
# Weekend Mid Age Shopper  7.807765  25.0
# Weekend Old Age Shopper  7.814453  25.0

# %% [markdown]
# The order frequency is higher in weekdays than weekends. The prices frequency are almost the same

# %% [markdown]
# **Family Status and Orders of Day of week**

# %%
instacart_with_customers.groupby('Shopping-Family-Profile').agg({'days_since_last_order': ['min','mean','max'],'prices': ['min','mean','max']})
# Out:
#                                          days_since_last_order             \
#                                                            min       mean
# Shopping-Family-Profile
# Weekday Married with children Shopper                      0.0  11.460938
# Weekday Married with no children Shopper                   0.0  11.476562
# Weekday Single with dependents Shopper                     0.0  11.484375
# Weekday Single with no children Shopper                    0.0  11.445312
# Weekend Married with children Shopper                      0.0  10.921875
# Weekend Married with no children Shopper                   0.0  10.906250
# Weekend Single with dependents Shopper                     0.0  10.796875
# Weekend Single with no children Shopper                    0.0  10.867188
#
#                                                prices
#                                            max    min      mean   max
# Shopping-Family-Profile
# Weekday Married with children Shopper     30.0    1.0  7.809791  25.0
# Weekday Married with no children Shopper  30.0    1.0  7.813958  25.0
# Weekday Single with dependents Shopper    30.0    1.0  7.822469  25.0
# Weekday Single with no children Shopper   30.0    1.0  7.808322  25.0
# Weekend Married with children Shopper     30.0    1.0  7.775950  25.0
# Weekend Married with no children Shopper  30.0    1.0  7.785381  25.0
# Weekend Single with dependents Shopper    30.0    1.0  7.788325  25.0
# Weekend Single with no children Shopper   30.0    1.0  7.779512  25.0

# %% [markdown]
# The Order frequency is same across many sections of the family profile. Single with dependents shoppers shop more frquently in the weekends.

# %% [markdown]
# ### Question 8

# %% [markdown]
# **Compare your customer profiles with regions and departments. Can you identify a link between them?**

# %%
# I will perform the crosstab for the following variables with Region.

# %% [markdown]
# **Age**

# %%
age_region_crosstab = pd.crosstab(instacart_with_customers['Age-Profile'], instacart_with_customers['region'],dropna = False,normalize = 'columns')

# %%
#Checking the crosstab
age_region_crosstab
# Out:
# region        MidWest  NorthEast     South      West
# Age-Profile
# Adult        0.474366   0.460145  0.468621  0.471200
# Mid Age      0.263589   0.268323  0.268565  0.264228
# Old Age      0.262045   0.271531  0.262814  0.264573

# %%
# The Age Profiles are the same across all regions.

# %% [markdown]
# **Income**

# %%
income_region_crosstab = pd.crosstab(instacart_with_customers['Income-Profile'], instacart_with_customers['region'],dropna = False,normalize = 'columns')

# %%
income_region_crosstab
# Out:
# region             MidWest  NorthEast     South      West
# Income-Profile
# High-Income       0.260164   0.260477  0.253280  0.256008
# Low-Income        0.319571   0.318405  0.323667  0.325550
# Middle-Income     0.410111   0.412618  0.413510  0.408968
# Very-High-Income  0.010154   0.008500  0.009544  0.009473

# %%
# The Income profiles are almost similar for all the Regions

# %% [markdown]
# **Vegetarian Flag**

# %%
veg_region_crosstab = pd.crosstab(instacart_with_customers['Veg-Flag'], instacart_with_customers['region'],dropna = False,normalize = 'columns')

# %%
veg_region_crosstab
# Out:
# region        MidWest  NorthEast     South      West
# Veg-Flag
# Meat-Eating  0.988115   0.988159  0.988389  0.987934
# Vegetarian   0.011885   0.011841  0.011611  0.012066

# %%
#The Diet Style among customers are same across the regions.

# %% [markdown]
# **Family Status**

# %%
family_stats_region_crosstab = pd.crosstab(instacart_with_customers['Family-Status'], instacart_with_customers['region'],dropna = False,normalize = 'columns')

# %%
family_stats_region_crosstab
# Out:
# region                     MidWest  NorthEast     South      West
# Family-Status
# Married with children     0.464053   0.469197  0.470703  0.472141
# Married with no children  0.236932   0.236116  0.229883  0.231373
# Single with dependents    0.048243   0.046851  0.049072  0.046593
# Single with no children   0.250772   0.247836  0.250342  0.249893

# %%
# The family status profiles among shoppers are same across all regions.

# %% [markdown]
# **Shopping Habits by Age and Day of the week**

# %%
shopping_habits_region_crosstab = pd.crosstab(instacart_with_customers['Shopping-Habits-Profile'], instacart_with_customers['region'],dropna = False,normalize = 'columns')

# %%
shopping_habits_region_crosstab
# Out:
# region                    MidWest  NorthEast     South      West
# Shopping-Habits-Profile
# Weekday Adult Shopper    0.300946   0.291663  0.297795  0.298288
# Weekday Mid Age Shopper  0.165584   0.169216  0.170292  0.166967
# Weekday Old Age Shopper  0.167428   0.172651  0.166376  0.167995
# Weekend Adult Shopper    0.173420   0.168483  0.170826  0.172911
# Weekend Mid Age Shopper  0.098005   0.099107  0.098274  0.097261
# Weekend Old Age Shopper  0.094618   0.098880  0.096437  0.096578

# %%
# The shopping habits among different category of Ages are same across all the Regions.

# %% [markdown]
# **Family Shopping Status and Orders of Day of week**

# %%
family_shopping_region_crosstab = pd.crosstab(instacart_with_customers['Shopping-Family-Profile'], instacart_with_customers['region'],dropna = False,normalize = 'columns')

# %%
family_shopping_region_crosstab
# Out:
# region                                     MidWest  NorthEast     South  \
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.169831   0.171961  0.172038
# Weekday Married with no children Shopper  0.086189   0.086484  0.083858
# Weekday Single with dependents Shopper    0.017886   0.017248  0.017582
# Weekday Single with no children Shopper   0.092137   0.090776  0.092059
# Weekend Married with children Shopper     0.294222   0.297236  0.298665
# Weekend Married with no children Shopper  0.150743   0.149632  0.146025
# Weekend Single with dependents Shopper    0.030357   0.029602  0.031491
# Weekend Single with no children Shopper   0.158636   0.157060  0.158282
#
# region                                        West
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.172678
# Weekday Married with no children Shopper  0.085017
# Weekday Single with dependents Shopper    0.017157
# Weekday Single with no children Shopper   0.091898
# Weekend Married with children Shopper     0.299464
# Weekend Married with no children Shopper  0.146356
# Weekend Single with dependents Shopper    0.029436
# Weekend Single with no children Shopper   0.157995

# %%
# The rates seem to be same across regions for all family shopping profile.

# %% [markdown]
# **Ordering Habits by Customer Loyalty**

# %%
habits_loyalty_crosstab = pd.crosstab(instacart_with_customers['loyalty_flag'], instacart_with_customers['spending_flag'],dropna = False,normalize = 'columns')

# %%
habits_loyalty_crosstab
# Out:
# spending_flag     High Spender  Low Spender
# loyalty_flag
# Loyal Customer        0.116081     0.318109
# New Customer          0.489754     0.191585
# Regular Customer      0.394164     0.490306

# %%
a = habits_loyalty_crosstab.plot(kind = 'bar')

a.legend(bbox_to_anchor=(1, 1.02))
plt.title('Spending Habits based on Loyalty')
# Out:
# Text(0.5, 1.0, 'Spending Habits based on Loyalty')

# %% [markdown]
# **Customer Profile By Departments**

# %% [markdown]
# ##### I will perform the crosstab for the following variables with Departments. Here are the Department Ids and value from the Excel sheet.
#
# Ids	department <br>
# 1	frozen <br>
# 2	other<br>
# 3	bakery<br>
# 4	produce<br>
# 5	alcohol<br>
# 6	international<br>
# 7	beverages<br>
# 8	pets<br>
# 9	dry goods pasta<br>
# 10	bulk<br>
# 11	personal care<br>
# 12	meat seafood<br>
# 13	pantry<br>
# 14	breakfast<br>
# 15	canned goods<br>
# 16	dairy eggs<br>
# 17	household<br>
# 18	babies<br>
# 19	snacks<br>
# 20	deli<br>
# 21	missing<br>

# %% [markdown]
# **Age**

# %%
age_department_crosstab = pd.crosstab(instacart_with_customers['Age-Profile'], instacart_with_customers['department_id'],dropna = False,normalize = 'columns')

# %%
#Printing the crosstab of age
age_department_crosstab
# Out:
# department_id        1         2         3         4         5         6   \
# Age-Profile
# Adult          0.469522  0.468325  0.469243  0.468948  0.468711  0.467367
# Mid Age        0.264823  0.271968  0.266756  0.265867  0.277307  0.269780
# Old Age        0.265654  0.259706  0.264001  0.265185  0.253982  0.262853
#
# department_id        7         8         9         10        11        12  \
# Age-Profile
# Adult          0.470659  0.461050  0.468286  0.463628  0.473493  0.466411
# Mid Age        0.263418  0.269946  0.267546  0.269054  0.264192  0.265418
# Old Age        0.265922  0.269004  0.264168  0.267318  0.262315  0.268171
#
# department_id        13        14        15        16        17        18  \
# Age-Profile
# Adult          0.468791  0.469611  0.467886  0.468114  0.469917  0.479623
# Mid Age        0.266205  0.268888  0.267674  0.267711  0.263474  0.262132
# Old Age        0.265003  0.261501  0.264441  0.264175  0.266609  0.258246
#
# department_id        19        20        21
# Age-Profile
# Adult          0.469094  0.470497  0.463866
# Mid Age        0.267529  0.265419  0.274452
# Old Age        0.263377  0.264084  0.261682

# %%
# Analysis of the Age Profile with departments are similar rates for all departments

# %% [markdown]
# **Income Profile**

# %%
income_department_crosstab = pd.crosstab(instacart_with_customers['Income-Profile'], instacart_with_customers['department_id'],dropna = False,normalize = 'columns')

# %%
income_department_crosstab
# Out:
# department_id           1         2         3         4         5         6   \
# Income-Profile
# High-Income       0.260284  0.252101  0.262001  0.263251  0.243773  0.263629
# Low-Income        0.314156  0.320603  0.307338  0.307986  0.313476  0.300951
# Middle-Income     0.414804  0.412003  0.417583  0.422422  0.393101  0.426317
# Very-High-Income  0.010756  0.015293  0.013078  0.006341  0.049650  0.009103
#
# department_id           7         8         9         10        11        12  \
# Income-Profile
# High-Income       0.245012  0.259558  0.266157  0.239754  0.255344  0.278122
# Low-Income        0.356396  0.304014  0.294838  0.357765  0.326374  0.265026
# Middle-Income     0.387820  0.413535  0.429389  0.401643  0.407593  0.446033
# Very-High-Income  0.010773  0.022893  0.009615  0.000839  0.010689  0.010819
#
# department_id           13        14        15        16        17        18  \
# Income-Profile
# High-Income       0.262836  0.247340  0.268605  0.260538  0.249343  0.270744
# Low-Income        0.307412  0.349615  0.294746  0.311195  0.333059  0.282061
# Middle-Income     0.419412  0.392054  0.426314  0.418281  0.399060  0.441416
# Very-High-Income  0.010341  0.010991  0.010335  0.009986  0.018539  0.005779
#
# department_id           19        20        21
# Income-Profile
# High-Income       0.221443  0.257462  0.261422
# Low-Income        0.411755  0.319912  0.324767
# Middle-Income     0.357224  0.414123  0.407925
# Very-High-Income  0.009578  0.008503  0.005886

# %%
# Some of the Analysis from the above crosstab are:
# 1) Spending among departments are of similar percentages for High-income customers.
# 2) Low-income customers spend more in departments 7(beverages), 10(bulk) and 19(snacks). This is expected, since people with low income prefer
# ordering items in bulk and help in savings. 
# 3) Middle-income customers form most of the percentages of orders across departments.
# 4) Very-high_income customers has highest percentage of orders in department 8 (pets). This forms a trend that Rich people having pets
# orders more within the Pets department.

# %% [markdown]
# **Vegetarian Flag**

# %%
veg_department_crosstab = pd.crosstab(instacart_with_customers['Veg-Flag'], instacart_with_customers['department_id'],dropna = False,normalize = 'columns')

# %%
veg_department_crosstab
# Out:
# department_id        1         2         3         4         5         6   \
# Veg-Flag
# Meat-Eating    0.989741  0.973905  0.994125  0.987712  0.914103  0.993987
# Vegetarian     0.010259  0.026095  0.005875  0.012288  0.085897  0.006013
#
# department_id        7         8         9         10        11   12  \
# Veg-Flag
# Meat-Eating    0.972374  0.986328  0.995847  0.980592  0.976122  1.0
# Vegetarian     0.027626  0.013672  0.004153  0.019408  0.023878  0.0
#
# department_id        13        14        15   16        17       18        19  \
# Veg-Flag
# Meat-Eating    0.990608  0.988403  0.993809  1.0  0.966839  0.99453  0.977967
# Vegetarian     0.009392  0.011597  0.006191  0.0  0.033161  0.00547  0.022033
#
# department_id       20        21
# Veg-Flag
# Meat-Eating    0.99314  0.988705
# Vegetarian     0.00686  0.011295

# %%
# As we can see, the data set include lot of meat-eating customers for Instacart.

# %% [markdown]
# **Family Status**

# %%
family_stats_department_crosstab = pd.crosstab(instacart_with_customers['Family-Status'], instacart_with_customers['department_id'],dropna = False,normalize = 'columns')

# %%
family_stats_department_crosstab
# Out:
# department_id                   1         2         3         4         5   \
# Family-Status
# Married with children     0.470661  0.458543  0.467286  0.469301  0.457956
# Married with no children  0.231456  0.235981  0.233722  0.232673  0.229648
# Single with dependents    0.048566  0.052658  0.047885  0.047433  0.057880
# Single with no children   0.249317  0.252818  0.251107  0.250593  0.254515
#
# department_id                   6         7         8         9         10  \
# Family-Status
# Married with children     0.464247  0.470034  0.460651  0.470727  0.470396
# Married with no children  0.235711  0.232707  0.230259  0.232762  0.241749
# Single with dependents    0.048557  0.046363  0.057514  0.048120  0.048419
# Single with no children   0.251485  0.250897  0.251576  0.248391  0.239435
#
# department_id                   11        12        13        14        15  \
# Family-Status
# Married with children     0.468760  0.471741  0.468862  0.466968  0.470631
# Married with no children  0.233370  0.234766  0.234114  0.235310  0.233479
# Single with dependents    0.047617  0.047933  0.048136  0.049402  0.047928
# Single with no children   0.250252  0.245560  0.248888  0.248320  0.247962
#
# department_id                   16        17        18        19        20  \
# Family-Status
# Married with children     0.467712  0.472522  0.474851  0.470105  0.468938
# Married with no children  0.234043  0.235060  0.226330  0.232770  0.230885
# Single with dependents    0.048305  0.047689  0.047536  0.047502  0.047957
# Single with no children   0.249940  0.244729  0.251282  0.249623  0.252219
#
# department_id                   21
# Family-Status
# Married with children     0.470692
# Married with no children  0.230530
# Single with dependents    0.051645
# Single with no children   0.247133

# %%
# The Analysis for the Family status is as follows:
# 1) Married With Children shoopers orders constitute most percentage of orders with most departments as this sector forms major customer base.
# 2) Single people spend more on orders from Department 2(Other), 5(Alcohol) and 8(Pets)

# %% [markdown]
# **Shopping Habits by Age and Day of the week**

# %%
shopping_habits_department_crosstab = pd.crosstab(instacart_with_customers['Shopping-Habits-Profile'], instacart_with_customers['department_id'],dropna = False,normalize = 'index')

# %%
shopping_habits_department_crosstab
# Out:
# department_id                  1         2         3         4         5   \
# Shopping-Habits-Profile
# Weekday Adult Shopper    0.069959  0.001183  0.036214  0.284400  0.005640
# Weekday Mid Age Shopper  0.069606  0.001189  0.036265  0.283854  0.005898
# Weekday Old Age Shopper  0.070024  0.001164  0.036228  0.284716  0.005347
# Weekend Adult Shopper    0.067394  0.001006  0.036146  0.306312  0.003176
# Weekend Mid Age Shopper  0.066862  0.001067  0.036225  0.306264  0.003298
# Weekend Old Age Shopper  0.067851  0.000985  0.035865  0.307841  0.003167
#
# department_id                  6         7         8         9         10  \
# Shopping-Habits-Profile
# Weekday Adult Shopper    0.008087  0.086513  0.003155  0.026086  0.001064
# Weekday Mid Age Shopper  0.008279  0.085416  0.003259  0.026226  0.001089
# Weekday Old Age Shopper  0.008083  0.086883  0.003277  0.026094  0.001084
# Weekend Adult Shopper    0.008610  0.077521  0.002631  0.027753  0.001038
# Weekend Mid Age Shopper  0.008660  0.076343  0.002712  0.027985  0.001060
# Weekend Old Age Shopper  0.008550  0.077224  0.002696  0.027750  0.001067
#
# department_id                  11        12        13        14        15  \
# Shopping-Habits-Profile
# Weekday Adult Shopper    0.014416  0.021254  0.059187  0.021915  0.031939
# Weekday Mid Age Shopper  0.014353  0.021264  0.059373  0.022079  0.032289
# Weekday Old Age Shopper  0.014234  0.021594  0.059497  0.021540  0.032297
# Weekend Adult Shopper    0.013116  0.022612  0.055479  0.021376  0.034491
# Weekend Mid Age Shopper  0.012596  0.022744  0.055278  0.021622  0.034589
# Weekend Old Age Shopper  0.012745  0.023176  0.055271  0.021264  0.034053
#
# department_id                  16        17        18        19        20  \
# Shopping-Habits-Profile
# Weekday Adult Shopper    0.166490  0.023919  0.013406  0.090909  0.032118
# Weekday Mid Age Shopper  0.167812  0.023594  0.012873  0.091320  0.031723
# Weekday Old Age Shopper  0.166486  0.024218  0.012794  0.090295  0.032012
# Weekend Adult Shopper    0.165812  0.020950  0.013310  0.085967  0.033260
# Weekend Mid Age Shopper  0.167019  0.020782  0.012882  0.086483  0.033398
# Weekend Old Age Shopper  0.166032  0.020784  0.012710  0.085890  0.033008
#
# department_id                  21
# Shopping-Habits-Profile
# Weekday Adult Shopper    0.002149
# Weekday Mid Age Shopper  0.002240
# Weekday Old Age Shopper  0.002133
# Weekend Adult Shopper    0.002042
# Weekend Mid Age Shopper  0.002131
# Weekend Old Age Shopper  0.002071

# %%
#The pattern of distirbution of orders across departments seem to be of similar percentages.
# Weekend Adult Shoppers prefer ordering from department 15(Canned Goods) and 4(Produce).
# Weekday Old Age Shoppers prefer 4(Produce).

# %% [markdown]
# **Family Shopping Status and Orders of Day of week**

# %%
family_shopping_department_crosstab = pd.crosstab(instacart_with_customers['Shopping-Family-Profile'], instacart_with_customers['department_id'],dropna = False,normalize = 'columns')

# %%
family_shopping_department_crosstab
# Out:
# department_id                                   1         2         3   \
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.168090  0.151360  0.170705
# Weekday Married with no children Shopper  0.082748  0.079221  0.085364
# Weekday Single with dependents Shopper    0.017342  0.018985  0.017401
# Weekday Single with no children Shopper   0.089502  0.082858  0.091777
# Weekend Married with children Shopper     0.302571  0.307184  0.296581
# Weekend Married with no children Shopper  0.148707  0.156761  0.148358
# Weekend Single with dependents Shopper    0.031224  0.033672  0.030485
# Weekend Single with no children Shopper   0.159815  0.169959  0.159330
#
# department_id                                   4         5         6   \
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.179947  0.115000  0.176050
# Weekday Married with no children Shopper  0.089214  0.055948  0.088541
# Weekday Single with dependents Shopper    0.018176  0.014041  0.018314
# Weekday Single with no children Shopper   0.096535  0.062493  0.096374
# Weekend Married with children Shopper     0.289354  0.342956  0.288197
# Weekend Married with no children Shopper  0.143459  0.173700  0.147170
# Weekend Single with dependents Shopper    0.029256  0.043840  0.030243
# Weekend Single with no children Shopper   0.154058  0.192022  0.155111
#
# department_id                                   7         8         9   \
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.159745  0.149126  0.178524
# Weekday Married with no children Shopper  0.079062  0.075054  0.089105
# Weekday Single with dependents Shopper    0.015863  0.018851  0.018324
# Weekday Single with no children Shopper   0.085742  0.081123  0.094838
# Weekend Married with children Shopper     0.310289  0.311525  0.292203
# Weekend Married with no children Shopper  0.153644  0.155205  0.143657
# Weekend Single with dependents Shopper    0.030500  0.038663  0.029796
# Weekend Single with no children Shopper   0.165155  0.170453  0.153553
#
# department_id                                   10        11        12  \
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.168629  0.159163  0.180577
# Weekday Married with no children Shopper  0.086570  0.080289  0.088967
# Weekday Single with dependents Shopper    0.017412  0.015848  0.018164
# Weekday Single with no children Shopper   0.088248  0.086098  0.093794
# Weekend Married with children Shopper     0.301767  0.309597  0.291164
# Weekend Married with no children Shopper  0.155179  0.153082  0.145799
# Weekend Single with dependents Shopper    0.031007  0.031769  0.029769
# Weekend Single with no children Shopper   0.151187  0.164155  0.151766
#
# department_id                                   13        14        15  \
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.163716  0.169484  0.179651
# Weekday Married with no children Shopper  0.081659  0.084568  0.089219
# Weekday Single with dependents Shopper    0.017039  0.017685  0.018227
# Weekday Single with no children Shopper   0.087886  0.089616  0.095051
# Weekend Married with children Shopper     0.305146  0.297484  0.290980
# Weekend Married with no children Shopper  0.152456  0.150743  0.144260
# Weekend Single with dependents Shopper    0.031097  0.031717  0.029702
# Weekend Single with no children Shopper   0.161002  0.158704  0.152911
#
# department_id                                   16        17        18  \
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.170808  0.158042  0.172621
# Weekday Married with no children Shopper  0.085218  0.078936  0.081861
# Weekday Single with dependents Shopper    0.017461  0.016053  0.017067
# Weekday Single with no children Shopper   0.091743  0.082038  0.093430
# Weekend Married with children Shopper     0.296904  0.314480  0.302231
# Weekend Married with no children Shopper  0.148825  0.156125  0.144468
# Weekend Single with dependents Shopper    0.030844  0.031635  0.030469
# Weekend Single with no children Shopper   0.158197  0.162691  0.157852
#
# department_id                                   19        20        21
# Shopping-Family-Profile
# Weekday Married with children Shopper     0.166444  0.175776  0.167199
# Weekday Married with no children Shopper  0.082049  0.086655  0.082276
# Weekday Single with dependents Shopper    0.016917  0.018192  0.018208
# Weekday Single with no children Shopper   0.088296  0.094419  0.088061
# Weekend Married with children Shopper     0.303662  0.293163  0.303493
# Weekend Married with no children Shopper  0.150721  0.144230  0.148254
# Weekend Single with dependents Shopper    0.030584  0.029766  0.033437
# Weekend Single with no children Shopper   0.161327  0.157800  0.159072

# %%
family_shopping_department_crosstab.max(axis = 1)
# Out:
# Shopping-Family-Profile
# Weekday Married with children Shopper       0.180577
# Weekday Married with no children Shopper    0.089219
# Weekday Single with dependents Shopper      0.018985
# Weekday Single with no children Shopper     0.096535
# Weekend Married with children Shopper       0.342956
# Weekend Married with no children Shopper    0.173700
# Weekend Single with dependents Shopper      0.043840
# Weekend Single with no children Shopper     0.192022
# dtype: float64

# %%
#Analysis of the above family shopping pattern by departments.
# 1) Weekday shoppers prefer ordering from department 12(Meat), 4(Produce) and 2(Other)
# 2) Weekend Shoppers prefer ordering from department 4(Alcohol). Most people order alcohol for social occasions over the weekend.

# %% [markdown]
# ## Question 9

# %% [markdown]
# **Produce suitable charts to illustrate your results and export them in your project folder.**

# %% [markdown]
# **Regions**

# %% [markdown]
# **Number of Customers by Region**

# %%
Region_customers = instacart_with_customers['region'].value_counts().plot.pie(autopct = '%1.1f%%')
plt.title('Percentage of Customers by Region')
# Out:
# Text(0.5, 1.0, 'Percentage of Customers by Region')

# %%
#Saving the visualization
Region_customers.figure.savefig(os.path.join(path,'Analysis','Visualizations','Region_customers.png'))

# %% [markdown]
# **Age**

# %%
Age_region_bar = age_region_crosstab.plot.bar()

# %%
#Saving the visualization
Age_region_bar.figure.savefig(os.path.join(path,'Analysis','Visualizations','Age_Region.png'))

# %% [markdown]
# **Income**

# %%
Income_region_bar = income_region_crosstab.plot.bar()

# %%
#Saving the visualization
Income_region_bar.figure.savefig(os.path.join(path,'Analysis','Visualizations','Income_Region.png'))

# %% [markdown]
# **Vegetarian flag**

# %%
Veg_bar = veg_region_crosstab.plot.bar()

# %%
#Saving the Visualization
Veg_bar.figure.savefig(os.path.join(path,'Analysis','Visualizations','Veg_Flag.png'))

# %% [markdown]
# **Shopping Habits by Age and Day of week**

# %%
Shopping_Region_bar = shopping_habits_region_crosstab.plot.bar()

# %%
Shopping_Region_bar.figure.savefig(os.path.join(path,'Analysis','Visualizations','Shopping_Region_bar.png'))

# %% [markdown]
# **Family Shopping Status and Order by Day of Week**

# %%
Family_Shopping_Region = family_shopping_region_crosstab.plot.bar()

# %%
Family_Shopping_Region.figure.savefig(os.path.join(path,'Analysis','Visualizations','Shopping_Family_Profile_Region_bar.png'))

# %% [markdown]
# **Departments**

# %% [markdown]
# **Number of Orders per Departments**

# %%
instacart_with_customers['department_id'].value_counts(dropna = False).plot.barh( )
# Out:
# <AxesSubplot: >

# %% [markdown]
# **Age Profile and Departments**

# %%
age_department = sns.heatmap(age_department_crosstab, cmap="Reds", linewidth=0.50, xticklabels=True, yticklabels=True)

# %%
#Saving the Visualization
age_department.figure.savefig(os.path.join(path,'Analysis','Visualizations','Department_Age_Heatmap.png'))

# %% [markdown]
# **Income Profile and Departments**

# %%
income_department = sns.heatmap(income_department_crosstab, cmap="Reds", linewidth=0.50, xticklabels=True, yticklabels=True)

# %%
income_department.figure.savefig(os.path.join(path,'Analysis','Visualizations','Department_Income_Heatmap.png'))

# %% [markdown]
# **Vegetarian Flag**

# %%
veg_department = sns.heatmap(veg_department_crosstab, cmap="Reds", linewidth=0.50, xticklabels=True, yticklabels=True)

# %%
veg_department.figure.savefig(os.path.join(path,'Analysis','Visualizations','Department_Veg_Flag_Heatmap.png'))

# %% [markdown]
# **Family Status**

# %%
family_stats_department = sns.heatmap(family_stats_department_crosstab, cmap="Reds", linewidth=0.50, xticklabels=True, yticklabels=True)

# %%
family_stats_department.figure.savefig(os.path.join(path,'Analysis','Visualizations','Department_Family_stats_Heatmap.png'))

# %% [markdown]
# **Shopping Habits by Age and Day of Week**

# %%
shopping_habits_department = sns.heatmap(shopping_habits_department_crosstab, cmap="Reds", linewidth=1, xticklabels=True, yticklabels=True)

# %%
shopping_habits_department.figure.savefig(os.path.join(path,'Analysis','Visualizations','Department_Shopping_habits_Heatmap.png'))

# %% [markdown]
# **Family Shopping Status and Order of Week by Department**

# %%
shopping_family_department = sns.heatmap(family_shopping_department_crosstab, cmap="Reds", linewidth=1, xticklabels=True, yticklabels=True)

# %%
shopping_family_department.figure.savefig(os.path.join(path,'Analysis','Visualizations','Department_Shopping_family_Heatmap.png'))

# %% [markdown]
# ## Question 10

# %% [markdown]
# **Tidy up your script, export your final data set, and save your notebook.**

# %%
#instacart_with_customers.to_pickle(os.path.join(path,'Data','Prepared Data','instacart_with_customers_final.pkl'))

# %%
instacart_with_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 38 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   order_id                 int64
#  1   user_id                  object
#  2   order_number             int16
#  3   order_day_of_week        int8
#  4   order_hour_of_day        int8
#  5   days_since_last_order    float16
#  6   product_id               int64
#  7   add_to_cart_order        int64
#  8   reordered                int8
#  9   product_name             object
#  10  aisle_id                 int64
#  11  department_id            int64
#  12  prices                   float64
#  13  price_range_loc          object
#  14  busiest_day              object
#  15  Busiest_days             object
#  16  busiest_period_of_day    object
#  17  max_order                int8
#  18  loyalty_flag             object
#  19  average_price            float64
#  20  spending_flag            object
#  21  order_frequency_flag     object
#  22  gender                   object
#  23  state                    object
#  24  age                      int8
#  25  date_joined              object
#  26  number_dependents        int8
#  27  marital_status           object
#  28  income                   int64
#  29  region                   object
#  30  Order_Flag               object
#  31  Age-Profile              object
#  32  Income-Profile           object
#  33  Veg-Flag                 object
#  34  Dependent-Flag           object
#  35  Family-Status            object
#  36  Shopping-Habits-Profile  object
#  37  Shopping-Family-Profile  object
# dtypes: float16(1), float64(2), int16(1), int64(6), int8(6), object(22)
# memory usage: 7.8+ GB
